# %%
import fileinput
import matplotlib.pyplot as plt

Type1Yes = 0
Type2Yes = 0
Type3Yes = 0

Type1No = 0
Type2No = 0
Type3No = 0

Type1TimesList = []
Type2TimesList = []
Type3TimesList = []

def switch_caseYes(argument, argument2):
    global Type1Yes, Type2Yes, Type3Yes, Type1Times, Type2Times, Type3Times
    if argument == "Child":
        Type1Yes += 1
        Type1TimesList.append(argument2)
    elif argument == "Adult":
        Type2Yes += 1
        Type2TimesList.append(argument2)
    elif argument == "Senior":
        Type3Yes += 1
        Type3TimesList.append(argument2)
    else:
        print("Invalid case")

def switch_caseNo(argument, argument2):
    global Type1No, Type2No, Type3No, Type1Times, Type2Times, Type3Times
    if argument == "Child":
        Type1No += 1
        Type1TimesList.append(argument2)
    elif argument == "Adult":
        Type2No += 1
        Type2TimesList.append(argument2)
    elif argument == "Senior":
        Type3No += 1
        Type3TimesList.append(argument2)
    else:
        print("Invalid case")


# User input for file name
filename = input("Enter the data file name (.csv): ")
scan = open(filename)

# Reading data
for line in scan:
    arrayLine = line.split()
    if arrayLine[1] == 'Y':
        switch_caseYes(arrayLine[0], int(arrayLine[2]))
    else:
        switch_caseNo(arrayLine[0], int(arrayLine[2]))

Type1= Type1Yes + Type1No
Type2= Type2Yes + Type2No
Type3= Type3Yes + Type3No

#Proporçao de Individuos que recomendam o parque por cada grupo etario
if(Type1 != 0):

    pType1Yes = (Type1Yes/Type1)
    print(f"The proportion of Childs who would recommend the park to others: {pType1Yes}\n")

if(Type2 != 0):

    pType2Yes = (Type2Yes/Type2)
    print(f"The proportion of Adult who would recommend the park to others: {pType2Yes}\n")

if(Type3 != 0):

    pType3Yes = (Type3Yes/Type3)
    print(f"The proportion of Senior who would recommend the park to others: {pType3Yes}\n")


    

if(Type1Yes+Type1No != 0):
    plt.boxplot(Type1TimesList)
    plt.title('Boxplot of monthly frequency of use of Childrens')
    plt.ylabel('Times')
    plt.show()
    
if(Type2Yes+Type2No != 0):
    plt.boxplot(Type2TimesList)
    plt.title('Boxplot of monthly frequency of use of Adult')
    plt.ylabel('Times')
    plt.show()
    
if(Type3Yes+Type3No != 0):
    plt.boxplot(Type3TimesList)
    plt.title('Boxplot of monthly frequency of use of Senior')
    plt.ylabel('Times')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 46
#      44 # User input for file name
#      45 filename = input("Enter the data file name (.csv): ")
# ---> 46 scan = open(filename)
#      48 # Reading data
#      49 for line in scan:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.csv'
